# %%
with open('./out.log') as f:
    data = f.read()

# %%
raw_data = [float(s.strip()) for s in data.split(' ') if (len(s.strip()) > 0)]

# %%
import pandas as pd

# %%
df = pd.Series(raw_data)

# %%
from matplotlib import pyplot as plt

# %%
# %matplotlib inline

n = 3

df[n*512:(n+2)*512].plot.line(figsize=(16, 8), ax=ax)

# %%
# %matplotlib inline

df.plot.line(figsize=(16, 8))
